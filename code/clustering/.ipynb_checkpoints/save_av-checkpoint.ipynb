# %%
# !pip install imageio pillow
# Out:
# Collecting imageio
#   Using cached imageio-2.37.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting pillow
#   Using cached pillow-12.2.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.8 kB)
# Collecting numpy (from imageio)
#   Using cached numpy-2.4.6.tar.gz (20.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [19 lines of output]
#       + /home1/09967/dongahkim0223/miniconda3/bin/python /tmp/pip-install-hskxj24p/numpy_9f68bca1d06b4b4b837da8ca4661a113/vendored-meson/meson/meson.py setup /tmp/pip-install-hskxj24p/numpy_9f68bca1d06b4b4b837da8ca4661a113 /tmp/pip-install-hskxj24p/numpy_9f68bca1d06b4b4b837da8ca4661a113/.mesonpy-j0o7b2lp -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=/tmp/pip-install-hskxj24p/numpy_9f68bca1d06b4b4b837da8ca4661a113/.mesonpy-j0o7b2lp/meson-python-native-file.ini
#       The Meson build system
#       Version: 1.9.2
#       Source dir: /tmp/pip-install-hskxj24p/numpy_9f68bca1d06b4b4b837da8ca4661a113
#       Build dir: /tmp/pip-install-hskxj24p/numpy_9f68bca1d06b4b4b837da8ca4661a113/.mesonpy-j0o7b2lp
#       Build type: native build
#       Project name: NumPy
#       Project version: 2.4.6
#       C compiler for the host machine: cc (gcc 4.8.5 "cc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)")
#       C linker for the host machine: cc ld.bfd 2.32
#       C++ compiler for the host machine: c++ (gcc 8.3.0 "c++ (GCC) 8.3.0")
#       C++ linker for the host machine: c++ ld.bfd 2.32
#       Cython compiler for the host machine: cython (cython 3.2.5)
#       Host machine cpu family: x86_64
#       Host machine cpu: x86_64
#
#       ../meson.build:25:4: ERROR: Problem encountered: NumPy requires GCC >= 9.3
#
#       A full log can be found at /tmp/pip-install-hskxj24p/numpy_9f68bca1d06b4b4b837da8ca4661a113/.mesonpy-j0o7b2lp/meson-logs/meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import sys
print(sys.executable)

# %%
import imageio.v2 as imageio
import os

methods = ["redcap", "clustergeo", "skater"]
seasons = ["2023-24", "2024-25", "2025-26"]

base = "/work2/09967/dongahkim0223/frontera/Spatial_clustering"

for method in methods:
    for season in seasons:
        files = [
            f"{base}/figures/cluster_combine2/county_{method}_exclude_{season}_k{i}.png"
            for i in range(5, 26)
        ]

        images = []
        missing = False

        for f in files:
            if not os.path.exists(f):
                print("MISSING:", f)
                missing = True
                break
            print("READ:", f)
            images.append(imageio.imread(f))

        if missing:
            print(f"Skipping {method}-{season}")
            continue

        outfile = f"{base}/figures/county_{method}_{season}_animation2.gif"
        imageio.mimsave(outfile, images, duration=1.0)

        print("SAVED:", outfile)

# %%
import sys
print(sys.executable)
# Out:
# /home1/09967/dongahkim0223/miniconda3/envs/flusion/bin/python

# %%
# !{sys.executable} -m pip show imageio
# Out:
# WARNING: Package(s) not found: imageio

# %%
import sys
# !{sys.executable} -m pip install imageio pillow
# Out:
# Collecting imageio
#   Using cached imageio-2.37.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: pillow in /home1/09967/dongahkim0223/miniconda3/envs/flusion/lib/python3.11/site-packages (10.4.0)
# Requirement already satisfied: numpy in /home1/09967/dongahkim0223/miniconda3/envs/flusion/lib/python3.11/site-packages (from imageio) (1.26.4)
# Downloading imageio-2.37.3-py3-none-any.whl (317 kB)
# Installing collected packages: imageio
# Successfully installed imageio-2.37.3

# %%
# !{sys.executable} -m pip show imageio
# Out:
# Name: ImageIO
# Version: 2.37.3
# Summary: Read and write images and video across all major formats. Supports scientific and volumetric data.
# Home-page: https://github.com/imageio/imageio
# Author: ImageIO contributors
# Author-email:
# License:
# Location: /home1/09967/dongahkim0223/miniconda3/envs/flusion/lib/python3.11/site-packages
# Requires: numpy, pillow
# Required-by:

# %%
import imageio.v2 as imageio
